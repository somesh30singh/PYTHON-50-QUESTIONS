# %% [markdown]
# # Question 43: Convert Binary to Decimal.

# %% [raw]
# Write a function to convert a binary number (as a string) to a decimal.
# --> Example:
#     Input: "1011"
#     Expected Output: 11

# %%
binary = "1011"
decimal = 0
power = 0

for digit in reversed(binary):
    if digit == "1":
        decimal = decimal +2**power
    power = power + 1
print(decimal)
# Out:
# 11

# %%
def binary_converter( binary1 : str) ->int:
    """
        Converts a binary number to its decimal equivalent.

        Parameters:
        binary (str): A string representing a binary number 
                      containing only 0s and 1s.
    
        Returns:
        int: The decimal equivalent of the binary number.
    
        Raises:
        TypeError: If the input is not a string.
        ValueError: If the input contains characters other than 0 and 1
                    or if the string is empty.
    """
    if not isinstance(binary1,str):
        raise TypeError("INPUT MUST BE A STRING")

    if len(binary) == 0:
        raise ValueError("INPUT SHOULD NOT BE EMPTY")

    final_result = 0
    power = 0

    for digit in reversed(binary1):
        if digit == "1":
            final_result = final_result +2** power
        power = power +1
    return final_result

if __name__ == "__main__":
    try:
        user_input = input("PLEASE ENTER YOUR TEXT :")
        if not user_input.isdigit():
            raise TypeError("ERROR : PLEASE ENTER VALID INPUT")
        result = binary_converter(user_input)
        print(result)

    except(TypeError,ValueError) as error:
        print(error)

    except Exception as error:
        print(error)
# Out:
# PLEASE ENTER YOUR TEXT : 0
# 0

# %%
binary_converter("1011")
# Out:
# 11
