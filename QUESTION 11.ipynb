# %% [markdown]
# # Question 11: Find factorial number using recursion.

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1

    return n * factrial(n-1)

# %%
factorial(5)
# Out:
# 120

# %%
def find_factorial(numbers : int) -> int:
    """heck whether two strings are anagrams of each other.

    Args:
        text1 (str): First input string.
        text2 (str): Second input string.

    Returns:
        bool: True if both strings are anagrams, otherwise False.

    Raises:
        TypeError: If any input is not a string.
        ValueError: If input is negative.
    """

    if not isinstance(numbers, int):
        raise TypeError("Input should be an Integer")
    if numbers < 0:
        raise ValueError("Input should not be negative")

    if numbers == 0 or numbers == 1:
        return 1

    return numbers * find_factorial(numbers-1)


if __name__ == "__main__":
    try:
        user_input = input("ENTER NUMBER :")
        user_input = int(user_input)
    except ValueError:
        print("ERROR :","Please enter Valid input")
    else:
        try:
            result = find_factorial(user_input)
            print(f"Factorial number of {user_input} is : {result}")
        except(TypeError,ValueError) as error:
            print(error)
        except Exception as error:
            print(error)
# Out:
# ENTER NUMBER : 5
# Factorial number of 5 is : 120
