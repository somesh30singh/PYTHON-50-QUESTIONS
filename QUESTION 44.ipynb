# %% [markdown]
# # Question 44) Swap Two Variables Without Temporary Variable

# %% [raw]
# Write a program to swap the values of two variables without using a temporary variable.
# --> Example:
#     Input: a = 5
#            b = 10
#     Expected Output (after swapping):
#     a should become 10
#     b should become 5

# %%
a = 15
b = 10

#a,b = b,a
print(a)
print(b)
# Out:
# 15
# 10

# %%
def swap_variables(item1, item2):
    """
        Swaps two variables without using a temporary variable.

        Parameters:
        a (int or float): The first value.
        b (int or float): The second value.
    
        Returns:
        tuple: A tuple containing the swapped values (a, b).
    
        Raises:
        TypeError: If the inputs are not numeric values.
        
    """
    swap = item1, item2 = item2, item1
    return swap
if __name__ == "__main__":
    try:
        user_a = input("PLEASE ENTER YOUR ITEM_1 :")
        user_b = input("PLEASE ENTER YOUR ITEM_2 :")

        user_a,user_b = swap_variables(user_a,user_b)
        print("ITEM_1 AFTER SWAP :",user_a)
        print("ITEM_2 AFTER SWAP :",user_b)
    
    except Exception as error:
        print(error)
# Out:
# PLEASE ENTER YOUR ITEM_1 : 1234
# PLEASE ENTER YOUR ITEM_2 : 5678
# ITEM_1 AFTER SWAP : 5678
# ITEM_2 AFTER SWAP : 1234

# %%
swap_variabes(a,b)
# Out:
# (10, 15)
